# %% [markdown]
# For Single file

# %%
from docx import Document
import html
import re
import pandas as pd
import os

# ------------------- Helpers -------------------
def is_list_item(paragraph):
    return paragraph._element.pPr is not None and paragraph._element.pPr.numPr is not None

def convert_run_to_html(run):
    text = html.escape(run.text)
    if not text:
        return ""
    if run.bold:
        text = f"<strong>{text}</strong>"
    if run.italic:
        text = f"<em>{text}</em>"
    if run.underline:
        text = f"<u>{text}</u>"
    return text

def paragraph_to_html(paragraph):
    text = "".join(convert_run_to_html(run) for run in paragraph.runs)
    if not text.strip():
        return ""
    if is_list_item(paragraph):
        return f"<li>{text}</li>"
    style = getattr(paragraph.style, "name", "").lower()
    if "heading" in style:
        level = ''.join(filter(str.isdigit, style)) or "2"
        return f"<h{level}>{text}</h{level}>"
    return f"<p>{text}</p>"
# ------------------- Extractors -------------------
def extract_title(docx_path):
    doc = Document(docx_path)
    capture = False

    for i, para in enumerate(doc.paragraphs):
        text = para.text.strip()
        low = text.lower()
        if not text:
            continue

        # --- Case 1: Explicit "Report Title" subheading ---
        if not capture and "report title" in low:
            capture = True
            continue
        if capture and text:
            return text

        # --- Case 2: "Full Title (Long-Form)" format ---
        if "full title" in low:
            # Take next non-empty paragraph
            for j in range(i+1, len(doc.paragraphs)):
                nxt = doc.paragraphs[j].text.strip()
                if nxt:
                    return nxt

    return ""
# ✅ extract description (Heading 1 → Heading 7 only)
def extract_description(docx_path):
    doc = Document(docx_path)
    html_output = []
    inside_list = False
    capture = False  

    for para in doc.paragraphs:
        text = para.text.strip()
        if not text:
            continue
        low = text.lower()

        # --- Start Condition ---
        if not capture and "introduction and strategic context" in low:
            capture = True  

        # --- Stop Condition ---
        if capture and "report summary, faqs, and seo schema" in low:
            break  

        if capture:
            html_part = paragraph_to_html(para)

            if not html_part:
                continue

            if html_part.startswith("<li>"):
                if not inside_list:
                    html_output.append("<ul>")
                    inside_list = True
                html_output.append(html_part)
            else:
                if inside_list:
                    html_output.append("</ul>")
                    inside_list = False
                html_output.append(html_part)

    if inside_list:
        html_output.append("</ul>")

    return "\n".join(html_output)
# ✅ TOC (after Heading 9 / Table of Contents)
def extract_toc(docx_path):
    doc = Document(docx_path)
    html_output, inside_list, capture = [], False, False
    end_reached = False

    for para in doc.paragraphs:
        text = para.text.strip()
        low = text.lower()

        # Start condition
        if not capture and "table of contents" in low:
            capture = True
            continue

        if capture:
            # End condition = capture "List of Figures" + its items, then stop
            if "list of figures" in low:
                html_part = paragraph_to_html(para)
                if html_part:
                    html_output.append(html_part)   # add heading "List of Figures"
                end_reached = True
                continue  # don't break yet, because its children may follow

            if end_reached:
                # If koi aur heading/subheading mil gaya to yahan break
                style = getattr(para.style, "name","").lower()
                if "heading" in style or re.match(r"^\d+[\.\)]\s", text):
                    break  

            html_part = paragraph_to_html(para)
            if html_part:
                if html_part.startswith("<li>"):
                    if not inside_list:
                        html_output.append("<ul>")
                        inside_list = True
                    html_output.append(html_part)
                else:
                    if inside_list:
                        html_output.append("</ul>")
                        inside_list = False
                    html_output.append(html_part)

    if inside_list:
        html_output.append("</ul>")
    return "".join(html_output).strip()

# ✅ Methodology (FAQ Table or Paragraphs Qn:/A: format)
def extract_methodology(docx_path):
    from docx import Document
    import re, html

    doc = Document(docx_path)
    faqs, q_count = [], 0

    # --- Case 1: FAQ Table ---
    for table in doc.tables:
        headers = [cell.text.strip().lower() for cell in table.rows[0].cells]
        if "question" in headers and "answer" in headers:
            for row in table.rows[1:]:
                q_text = row.cells[0].text.strip()
                a_text = row.cells[1].text.strip()
                if q_text and a_text:
                    q_count += 1
                    faqs.append(
                        f"<p><strong>Q{q_count}: {html.escape(q_text)}</strong><br>"
                        f"A{q_count}: {html.escape(a_text)}</p>"
                    )
            if faqs:
                return "\n".join(faqs)

    # --- Case 2: Text-based FAQs ---
    capture, current_q = False, None
    for para in doc.paragraphs:
        text = para.text.strip()
        if not text:
            continue
        low = text.lower()

        # --- Start condition
        if not capture and ("top 5 faqs" in low or "faqs" in low or low.startswith("q1") or low.startswith("how ")):
            capture = True
            continue

        # --- Stop condition (don’t eat schemas!)
        if capture and (
            "breadcrumb schema" in low or 
            "faq schema" in low or 
            "json" in low or 
            "schema" in low or 
            text.strip().startswith("{")
        ):
            break

        if capture:
            # Inline Q... A...
            both_match = re.match(r"Q\d*[:.]\s*(.*?)\s*A\d*[:.]\s*(.*)", text, re.IGNORECASE)
            if both_match:
                q_count += 1
                faqs.append(
                    f"<p><strong>Q{q_count}: {html.escape(both_match.group(1).strip())}</strong><br>"
                    f"A{q_count}: {html.escape(both_match.group(2).strip())}</p>"
                )
                continue

            # Question
            q_match = re.match(r"Q\d*[:.]\s*(.*)", text, re.IGNORECASE)
            if q_match:
                current_q = q_match.group(1).strip()
                continue

            # Natural question
            if current_q is None and re.match(r"^(how|what|which|why|when|who)\b", low):
                current_q = text
                continue

            # Answer
            if current_q:
                q_count += 1
                faqs.append(
                    f"<p><strong>Q{q_count}: {html.escape(current_q)}</strong><br>"
                    f"A{q_count}: {html.escape(text)}</p>"
                )
                current_q = None

    return "\n".join(faqs)
# -------------------------------------------------------------Meta Discription--------------------------------
def extract_meta_description(docx_path):
    doc = Document(docx_path)
    capture = False
    for para in doc.paragraphs:
        text = para.text.strip()
        low = text.lower()
        if not capture and ("introduction" in low):
            capture = True
            continue
        if capture and text:
            return text
    return ""
# --------------------------------------------------------SEO Title----------------------------------------

def extract_seo_title(docx_path):
    doc = Document(docx_path)
    file_name = os.path.splitext(os.path.basename(docx_path))[0]  # File name without extension
    
    revenue_forecast = ""

    # --- Check tables for Report Coverage ---
    for table in doc.tables:
        headers = [cell.text.strip().lower() for cell in table.rows[0].cells]

        if "report attribute" in headers and "details" in headers:
            attr_idx = headers.index("report attribute")
            details_idx = headers.index("details")

            for row in table.rows[1:]:
                attr = row.cells[attr_idx].text.strip().lower()
                details = row.cells[details_idx].text.strip()

                if "revenue forecast in 2030" in attr:
                    # replace USD with $
                    revenue_forecast = details.replace("USD", "$").strip()
                    break

    if revenue_forecast:
        seo_title = f"{file_name} Market Size ({revenue_forecast}) 2030"
    else:
        seo_title = file_name  # fallback

    return seo_title
# --------------------------------------------------------BreadCrumb Text----------------------------------------
def extract_breadcrumb_text(docx_path):
    doc = Document(docx_path)
    file_name = os.path.splitext(os.path.basename(docx_path))[0]  # File name without extension
    
    revenue_forecast = ""

    # --- Check tables for Report Coverage ---
    for table in doc.tables:
        headers = [cell.text.strip().lower() for cell in table.rows[0].cells]

        if "report attribute" in headers and "details" in headers:
            attr_idx = headers.index("report attribute")
            details_idx = headers.index("details")

            for row in table.rows[1:]:
                attr = row.cells[attr_idx].text.strip().lower()
                details = row.cells[details_idx].text.strip()

                if "revenue forecast in 2030" in attr:
                    # replace USD with $
                    revenue_forecast = details.replace("USD", "$").strip()
                    break

    if revenue_forecast:
        seo_title = f"{file_name} Report 2030"
    else:
        seo_title = file_name  # fallback

    return seo_title
# ---------------------------------------------BreadCrumb Schema-----------------------------------------------------------------

def extract_breadcrumb_schema(docx_path):
    doc = Document(docx_path)
    paragraphs = [p.text.strip() for p in doc.paragraphs if p.text.strip()]

    capture = False
    breadcrumb_data = []

    for text in paragraphs:
        low = text.lower()

        # ✅ Start condition → JSON block must start with {
        if not capture and text.strip().startswith("{"):
            capture = True
        
        # ✅ End condition → stop when json copy or faq schema heading found
        if capture and ("json copy" in low or "faq schema" in low):
            break

        # ✅ Collect JSON block only
        if capture:
            breadcrumb_data.append(text)

    return "".join(breadcrumb_data).strip()

# -----------------------------------------------------FaqSchema-------------------------------
def extract_faq_schema(docx_path):
    doc = Document(docx_path)
    paragraphs = [p.text.strip() for p in doc.paragraphs if p.text.strip()]

    json_blocks = []
    current_block = []
    capture = False

    for text in paragraphs:
        if text.strip().startswith("{"):   # start of JSON
            capture = True
            current_block = [text]
            continue

        if capture:
            current_block.append(text)
            if text.strip().endswith("}"):   # end of JSON
                json_blocks.append("".join(current_block).strip())
                capture = False

    # ✅ Usually Breadcrumb = first JSON, FAQ Schema = second JSON
    if len(json_blocks) >= 2:
        return json_blocks[1]   # second JSON only (FAQ Schema)
    return ""

# ------------------- Runner -------------------

doc_path = r"C:\Users\Vishnu\Documents\extracted_docs\extracted_docs\Aerial Imaging Market.docx"
# title=extract_title(doc_path)
# description_html = extract_description(doc_path)
# toc_html = extract_toc(doc_path)
# methodology_html = extract_methodology(doc_path)
meta = extract_meta_description(doc_path)
# seo_title=extract_seo_title(doc_path)
# breadcrumb_text=extract_breadcrumb_text(doc_path)
sche2=extract_faq_schema(doc_path)
sche1=extract_breadcrumb_schema(doc_path)

# ✅ Save single file result in Excel
df = pd.DataFrame([{
    # "Title":title,
    # "Description": description_html,
    # "TOC": toc_html,
    # "Methodology": methodology_html,
    # "Meta Description": meta,
    # "SeoTitle": seo_title,
    # "BreadcrumbText": breadcrumb_text,
    'BreadcrumbText':sche1,
    'schema2':sche2,
    # 'BreadcrumbText':sche1
}])

output_path = r"C:\Users\Vishnu\Documents\extracted_docs\Day1.xlsx"
df.to_excel(output_path, index=False)

print(f"✅ Done! Extracted data saved in {output_path}")
# Out:
# ✅ Done! Extracted data saved in C:\Users\Vishnu\Documents\extracted_docs\Day1.xlsx

# %% [markdown]
# For Multiple File

# %%
from docx import Document
import html
import re
import pandas as pd
import os

# ------------------- Helpers -------------------
def is_list_item(paragraph):
    return paragraph._element.pPr is not None and paragraph._element.pPr.numPr is not None

def convert_run_to_html(run):
    text = html.escape(run.text)
    if not text:
        return ""
    if run.bold:
        text = f"<strong>{text}</strong>"
    if run.italic:
        text = f"<em>{text}</em>"
    if run.underline:
        text = f"<u>{text}</u>"
    return text

def paragraph_to_html(paragraph):
    text = "".join(convert_run_to_html(run) for run in paragraph.runs)
    if not text.strip():
        return ""
    if is_list_item(paragraph):
        return f"<li>{text}</li>"
    style = getattr(paragraph.style, "name", "").lower()
    if "heading" in style:
        level = ''.join(filter(str.isdigit, style)) or "2"
        return f"<h{level}>{text}</h{level}>"
    return f"<p>{text}</p>"
# ------------------- Extractors -------------------
def extract_title(docx_path):
    doc = Document(docx_path)
    capture = False

    for i, para in enumerate(doc.paragraphs):
        text = para.text.strip()
        low = text.lower()
        if not text:
            continue

        # --- Case 1: Explicit "Report Title" subheading ---
        if not capture and "report title" in low:
            capture = True
            continue
        if capture and text:
            return text

        # --- Case 2: "Full Title (Long-Form)" format ---
        if "full title" in low:
            # Take next non-empty paragraph
            for j in range(i+1, len(doc.paragraphs)):
                nxt = doc.paragraphs[j].text.strip()
                if nxt:
                    return nxt

    return ""
# ✅ extract description (Heading 1 → Heading 7 only)

def extract_description(docx_path):
    doc = Document(docx_path)
    html_output = []
    inside_list = False
    capture = False  

    for para in doc.paragraphs:
        text = para.text.strip()
        if not text:
            continue
        low = text.lower()

        # --- Start Condition ---
        if not capture and "introduction and strategic context" in low:
            capture = True  

        # --- Stop Condition ---
        if capture and "report summary, faqs, and seo schema" in low:
            break  

        if capture:
            html_part = paragraph_to_html(para)

            if not html_part:
                continue

            if html_part.startswith("<li>"):
                if not inside_list:
                    html_output.append("<ul>")
                    inside_list = True
                html_output.append(html_part)
            else:
                if inside_list:
                    html_output.append("</ul>")
                    inside_list = False
                html_output.append(html_part)

    if inside_list:
        html_output.append("</ul>")

    return "\n".join(html_output)
# ✅ TOC (after Heading 9 / Table of Contents)
def extract_toc(docx_path):
    doc = Document(docx_path)
    html_output, inside_list, capture = [], False, False
    end_reached = False

    for para in doc.paragraphs:
        text = para.text.strip()
        low = text.lower()

        # Start condition
        if not capture and "table of contents" in low:
            capture = True
            continue

        if capture:
            # End condition = capture "List of Figures" + its items, then stop
            if "list of figures" in low:
                html_part = paragraph_to_html(para)
                if html_part:
                    html_output.append(html_part)   # add heading "List of Figures"
                end_reached = True
                continue  # don't break yet, because its children may follow

            if end_reached:
                # If koi aur heading/subheading mil gaya to yahan break
                style = getattr(para.style, "name","").lower()
                if "heading" in style or re.match(r"^\d+[\.\)]\s", text):
                    break  

            html_part = paragraph_to_html(para)
            if html_part:
                if html_part.startswith("<li>"):
                    if not inside_list:
                        html_output.append("<ul>")
                        inside_list = True
                    html_output.append(html_part)
                else:
                    if inside_list:
                        html_output.append("</ul>")
                        inside_list = False
                    html_output.append(html_part)

    if inside_list:
        html_output.append("</ul>")
    return "".join(html_output).strip()


# ✅ Methodology (FAQ Table or Paragraphs Qn:/A: format)
def extract_methodology(docx_path):
    from docx import Document
    import re, html

    doc = Document(docx_path)
    faqs, q_count = [], 0

    # --- Case 1: FAQ Table ---
    for table in doc.tables:
        headers = [cell.text.strip().lower() for cell in table.rows[0].cells]
        if "question" in headers and "answer" in headers:
            for row in table.rows[1:]:
                q_text = row.cells[0].text.strip()
                a_text = row.cells[1].text.strip()
                if q_text and a_text:
                    q_count += 1
                    faqs.append(
                        f"<p><strong>Q{q_count}: {html.escape(q_text)}</strong><br>"
                        f"A{q_count}: {html.escape(a_text)}</p>"
                    )
            if faqs:
                return "\n".join(faqs)  # ✅ return if table found

    # --- Case 2 & 3: Text-based FAQs ---
    capture = False
    current_q = None

    for para in doc.paragraphs:
        text = para.text.strip()
        if not text:
            continue
        low = text.lower()

        # ✅ Start condition
        if not capture and ("top 5 faqs" in low or low.startswith("how big")):
            capture = True
            continue

        # ✅ End condition
        if capture and ("breadcrumb" in low or "json-ld" in low or "schema" in low or "json copy" in low):
            break

        if capture:
            # --- Case 1: Question: ... Answer: ...
            qa_match = re.match(r"question[:：]\s*(.*)", text, re.IGNORECASE)
            if qa_match:
                current_q = qa_match.group(1).strip()
                continue
            ans_match = re.match(r"answer[:：]\s*(.*)", text, re.IGNORECASE)
            if ans_match and current_q:
                q_count += 1
                faqs.append(
                    f"<p><strong>Q{q_count}: {html.escape(current_q)}</strong><br>"
                    f"A{q_count}: {html.escape(ans_match.group(1).strip())}</p>"
                )
                current_q = None
                continue

            # --- Case 2: Q1: ... (ignore numbering) ---
            q_match = re.match(r"q?\d*[:.]\s*(.*)", text, re.IGNORECASE)
            if q_match and re.match(r"^(how|what|which|why|when|who)\b", q_match.group(1).lower()):
                current_q = q_match.group(1).strip()
                continue

            # --- Case 3: 1. How big ... ---
            q_num_match = re.match(r"\d+\.\s*(.*)", text)
            if q_num_match and re.match(r"^(how|what|which|why|when|who)\b", q_num_match.group(1).lower()):
                current_q = q_num_match.group(1).strip()
                continue

            # --- Case 4: Inline Q & A (Q... A...) ---
            both_match = re.match(r"Q\d*[:.]\s*(.*?)\s*A\d*[:.]\s*(.*)", text, re.IGNORECASE)
            if both_match:
                q_count += 1
                faqs.append(
                    f"<p><strong>Q{q_count}: {html.escape(both_match.group(1).strip())}</strong><br>"
                    f"A{q_count}: {html.escape(both_match.group(2).strip())}</p>"
                )
                continue

            # --- Answer line (if current_q is set) ---
            if current_q and text:
                q_count += 1
                faqs.append(
                    f"<p><strong>Q{q_count}: {html.escape(current_q)}</strong><br>"
                    f"A{q_count}: {html.escape(text)}</p>"
                )
                current_q = None

    return "\n".join(faqs)
def extract_methodology(docx_path):
    from docx import Document
    import re, html

    doc = Document(docx_path)
    faqs, q_count = [], 0

    # --- Case 1: FAQ Table ---
    for table in doc.tables:
        headers = [cell.text.strip().lower() for cell in table.rows[0].cells]
        if "question" in headers and "answer" in headers:
            for row in table.rows[1:]:
                q_text = row.cells[0].text.strip()
                a_text = row.cells[1].text.strip()
                if q_text and a_text:
                    q_count += 1
                    faqs.append(
                        f"<p><strong>Q{q_count}: {html.escape(q_text)}</strong><br>"
                        f"A{q_count}: {html.escape(a_text)}</p>"
                    )
            if faqs:
                return "\n".join(faqs)

    # --- Case 2: Text-based FAQs ---
    capture, current_q = False, None
    for para in doc.paragraphs:
        text = para.text.strip()
        if not text:
            continue
        low = text.lower()

        # --- Start condition
        if not capture and ("top 5 faqs" in low or "faqs" in low or low.startswith("q1") or low.startswith("how ")):
            capture = True
            continue

        # --- Stop condition (don’t eat schemas!)
        if capture and (
            "breadcrumb schema" in low or 
            "faq schema" in low or 
            "json" in low or 
            "schema" in low or 
            text.strip().startswith("{")
        ):
            break

        if capture:
            # Inline Q... A...
            both_match = re.match(r"Q\d*[:.]\s*(.*?)\s*A\d*[:.]\s*(.*)", text, re.IGNORECASE)
            if both_match:
                q_count += 1
                faqs.append(
                    f"<p><strong>Q{q_count}: {html.escape(both_match.group(1).strip())}</strong><br>"
                    f"A{q_count}: {html.escape(both_match.group(2).strip())}</p>"
                )
                continue

            # Question
            q_match = re.match(r"Q\d*[:.]\s*(.*)", text, re.IGNORECASE)
            if q_match:
                current_q = q_match.group(1).strip()
                continue

            # Natural question
            if current_q is None and re.match(r"^(how|what|which|why|when|who)\b", low):
                current_q = text
                continue

            # Answer
            if current_q:
                q_count += 1
                faqs.append(
                    f"<p><strong>Q{q_count}: {html.escape(current_q)}</strong><br>"
                    f"A{q_count}: {html.escape(text)}</p>"
                )
                current_q = None

    return "\n".join(faqs)
# -----------------------------------------------------------Meta Discription--------------------------------------------
def extract_meta_description(docx_path):
    doc = Document(docx_path)
    capture = False
    for para in doc.paragraphs:
        text = para.text.strip()
        low = text.lower()
        if not capture and ("introduction" in low):
            capture = True
            continue
        if capture and text:
            return text
    return ""

# -----------------------------------------------------------------------------SEO title-------------------------------------------------------------
def extract_seo_title(docx_path):
    doc = Document(docx_path)
    file_name = os.path.splitext(os.path.basename(docx_path))[0]  # File name without extension
    
    revenue_forecast = ""

    # --- Check tables for Report Coverage ---
    for table in doc.tables:
        headers = [cell.text.strip().lower() for cell in table.rows[0].cells]

        if "report attribute" in headers and "details" in headers:
            attr_idx = headers.index("report attribute")
            details_idx = headers.index("details")

            for row in table.rows[1:]:
                attr = row.cells[attr_idx].text.strip().lower()
                details = row.cells[details_idx].text.strip()

                if "revenue forecast in 2030" in attr:
                    # replace USD with $
                    revenue_forecast = details.replace("USD", "$").strip()
                    break

    if revenue_forecast:
        seo_title = f"{file_name} Size ({revenue_forecast}) 2030"
    else:
        seo_title = file_name  # fallback

    return seo_title
# --------------------------------------------------------BreadCrumb Text----------------------------------------
def extract_breadcrumb_text(docx_path):
    doc = Document(docx_path)
    file_name = os.path.splitext(os.path.basename(docx_path))[0]  # File name without extension
    
    revenue_forecast = ""

    # --- Check tables for Report Coverage ---
    for table in doc.tables:
        headers = [cell.text.strip().lower() for cell in table.rows[0].cells]

        if "report attribute" in headers and "details" in headers:
            attr_idx = headers.index("report attribute")
            details_idx = headers.index("details")

            for row in table.rows[1:]:
                attr = row.cells[attr_idx].text.strip().lower()
                details = row.cells[details_idx].text.strip()

                if "revenue forecast in 2030" in attr:
                    # replace USD with $
                    revenue_forecast = details.replace("USD", "$").strip()
                    break

    if revenue_forecast:
        seo_title = f"{file_name} Report 2030"
    else:
        seo_title = file_name  # fallback

    return seo_title

# ---------------------------------------------SkuCode-Extraction------------------------------
def extract_sku_code(docx_path):
    filename = os.path.basename(docx_path)
    sku_code = os.path.splitext(filename)[0].lower()
    return sku_code
# ---------------------------------------------URLRP------------------------------
def extract_sku_url(docx_path):
    filename = os.path.basename(docx_path)
    sku_code = os.path.splitext(filename)[0].lower()
    return sku_code

# ---------------------------------------------BreadCrumb Schema----------------------------
def extract_breadcrumb_schema(docx_path):
    doc = Document(docx_path)
    paragraphs = [p.text.strip() for p in doc.paragraphs if p.text.strip()]

    capture = False
    breadcrumb_data = []

    for text in paragraphs:
        low = text.lower()

        # ✅ Start condition → JSON block must start with {
        if not capture and text.strip().startswith("{"):
            capture = True
        
        # ✅ End condition → stop when json copy or faq schema heading found
        if capture and ("json copy" in low or "faq schema" in low):
            break

        # ✅ Collect JSON block only
        if capture:
            breadcrumb_data.append(text)

    return "".join(breadcrumb_data).strip()

# -----------------------------------------------------FaqSchema-------------------------------
def extract_faq_schema(docx_path):
    doc = Document(docx_path)
    paragraphs = [p.text.strip() for p in doc.paragraphs if p.text.strip()]

    json_blocks = []
    current_block = []
    capture = False

    for text in paragraphs:
        if text.strip().startswith("{"):   # start of JSON
            capture = True
            current_block = [text]
            continue

        if capture:
            current_block.append(text)
            if text.strip().endswith("}"):   # end of JSON
                json_blocks.append("".join(current_block).strip())
                capture = False

    # ✅ Usually Breadcrumb = first JSON, FAQ Schema = second JSON
    if len(json_blocks) >= 2:
        return json_blocks[1]   # second JSON only (FAQ Schema)
    return ""

# --------------------------------------------------------Runner------------------------------------------------------------

folder_path = r"C:\Users\Vishnu\Desktop\oldcontent\20-21-22-23-24-25 June Files\20-21-22-23-24-25 June Files"
output_path = r"C:\Users\Vishnu\Documents\extracted_docs\Extraction.xlsx"

all_data = []

for file in os.listdir(folder_path):
    if not file.endswith(".docx") or file.startswith("~$"):
        continue

    doc_path = os.path.join(folder_path, file)
    print(f"Processing: {file}")
    title = extract_title(doc_path)
    description_html = extract_description(doc_path)
    toc_html = extract_toc(doc_path)
    methodology_html = extract_methodology(doc_path)
    meta = extract_meta_description(doc_path)
    seo_title=extract_seo_title(doc_path)
    breadcrumb_text=extract_breadcrumb_text(doc_path)
    sku=extract_sku_code(doc_path)
    url=extract_sku_url(doc_path)
    schema1=extract_breadcrumb_schema(doc_path)
    schema2=extract_faq_schema(doc_path)
    # schema2=extract_faq_schema(doc_path)
    # schema2=extract_breadcrumb_schema2(doc_path)
   

    all_data.append({
        "File": file,
        "Title": title,
        "Description": description_html,
        "TOC": toc_html, 
        "Methodology": methodology_html,
        "Meta Description": meta,
        "SeoTitle": seo_title,
        "BreatdCrumb_Text":breadcrumb_text,
        "SkuCode":sku,
        'urlrp':url,
        "Schema1": schema1,
        'schema2':schema2
        })

df = pd.DataFrame(all_data)
df.to_excel(output_path, index=False)

print(f"✅ Done! Extracted data saved in {output_path}")
# Out:
# Processing: 3D Cardiac Mapping System Market.docx
# Processing: 3D Laparoscopy Imaging Market.docx
# Processing: 3D Medical Imaging Devices Market.docx
# Processing: 3D Printed Brain Model Market.docx
# Processing: 3D Ultrasound Market.docx
# Processing: Achondrogenesis Market.docx
# Processing: Active Phased Array Radar Market.docx
# Processing: Adult Spinal Deformity Market.docx
# Processing: Advanced Cardiovascular Life Support (ACLS) Market.docx
# Processing: Advanced Wound Dressings Market.docx
# Processing: Aeroderivative Sensor Market.docx
# Processing: Aerospace Accumulator Market.docx
# Processing: Aerospace And Defense C-Class Parts Market.docx
# Processing: Aerospace Cold Forgings Market.docx
# Processing: Aerospace Engine Vibration Monitoring System Market.docx
# Processing: Aerospace Filter Market.docx
# Processing: Aerospace Forging Market.docx
# Processing: Aerospace Fuel Tank Inerting System.docx
# Processing: Aerospace Insulation Market.docx
# Processing: Aerospace Pressure Bulkhead Market.docx
# Processing: Aerospace Riveting Equipment Market.docx
# Processing: Aerospace Titanium Market.docx
# Processing: Aerospace Wiring Harness Market.docx
# Processing: AI In Chemicals Market.docx
# Processing: AI In Precision Medicine Market.docx
# Processing: AI In Precision Oncology Market.docx
# Processing: AI In Prostate Cancer Diagnostics Market.docx
# Processing: AI In Sports Market.docx
# Processing: Air Cargo Security Equipment Market.docx
# Processing: Air Circuit Breaker Market.docx
# Processing: Air Transport Used Serviceable Material (USM) Market.docx
# Processing: Airborne Laser Obstacle Avoidance Monitoring System Market.docx
# Processing: Airborne Radars Market.docx
# Processing: Airborne Situational Awareness System Market.docx
# Processing: Aircraft Aileron Market.docx
# Processing: Aircraft Antenna Market.docx
# Processing: Aircraft Bolts Market.docx
# Processing: Aircraft Bracket Market.docx
# Processing: Aircraft Circuit Breaker Market.docx
# Processing: Aircraft Clamps Market.docx
# Processing: Aircraft Cooling Turbine Market.docx
# Processing: Aircraft Curtain Market.docx
# Processing: Aircraft Door Damper Market.docx
# Processing: Aircraft Elevator Market.docx
# Processing: Aircraft Engine Test Cells Market.docx
# Processing: Aircraft Generators Market.docx
# Processing: Aircraft Hydraulic System.docx
# Processing: Aircraft Nondestructive Testing (NDT) Market.docx
# Processing: Aircraft Overhead Stowage Bins Market.docx
# Processing: Aircraft Pumps Market.docx
# Processing: Aircraft Refueling Hose Market.docx
# Processing: Aircraft Seat Upholstery Market.docx
# Processing: Aircraft Sequencing System Market.docx
# Processing: Aircraft Struts And Rods Market.docx
# Processing: Aircraft Tube And Duct Assemblies Market.docx
# Processing: Aircraft Tugs Market.docx
# Processing: Aircraft Turbocharger Market.docx
# Processing: Aircraft Turn Coordinator Market.docx
# Processing: Aircraft Washing System Market.docx
# Processing: Airplane Machmeter Market.docx
# Processing: Airport Automation Market.docx
# Processing: Airport Logistics System Market.docx
# Processing: Airport Lounge Market.docx
# Processing: Airspeed Indicator Market.docx
# Processing: All Weather Landing System Market.docx
# Processing: Amblyopia Market.docx
# Processing: Anal Irrigation Systems Market.docx
# Processing: Anesthesia Monitoring Devices Market.docx
# Processing: Antepartum Monitoring Devices Market.docx
# Processing: Antibodies Contract Manufacturing Market.docx
# Processing: Antimicrobial Susceptibility Testing Market.docx
# Processing: Aortic Coarctation Market.docx
# Processing: Arterial Filter Market.docx
# Processing: Arteriovenous Fistula (AVF) Devices Market.docx
# Processing: Arthroscopy Market.docx
# Processing: Artificial Blood Vessels Market.docx
# Processing: Artificial Skin Market.docx
# Processing: Asthma Spacers Market.docx
# Processing: Astigmatism Market.docx
# Processing: At-home Blood Collection Devices Market.docx
# Processing: Attack Surface Management (ASM) Market.docx
# Processing: Augmented Bone Graft Market.docx
# Processing: Automated Sample Storage Systems Market.docx
# Processing: Autonomous Networks Market.docx
# Processing: Autosampler Market.docx
# Processing: Aviation Life Raft Market.docx
# Processing: Azimuth Thrusters Market.docx
# Processing: Backshell Market.docx
# Processing: Bag-on-Valve Technology Market.docx
# Processing: Beauty Devices Market.docx
# Processing: Bioabsorbable Stents Market.docx
# Processing: Bioactive Materials Market.docx
# Processing: Bioburden Testing Market.docx
# Processing: Biocompatible 3D Printing Materials Market.docx
# Processing: Biodegradable Implants Market.docx
# Processing: Bioimpedance Analyzers Market.docx
# Processing: Biological Stains Market.docx
# Processing: bionic eye market.docx
# Processing: Bioprosthetics Market.docx
# Processing: Biopsy Needles Market.docx
# Processing: Bioresorbable Vascular Scaffold Market.docx
# Processing: Biosensors Market.docx
# Processing: Biotechnology Reagents Market.docx
# Processing: Bladder Scanner Market.docx
# Processing: Blepharoplasty Market.docx
# Processing: Blood Coagulants Market.docx
# Processing: Blood Gas And Electrolyte Analyzer Market.docx
# Processing: Blood Group Typing Market.docx
# Processing: Blood Ketone Meter Market.docx
# Processing: Blood Pressure Cuffs Market.docx
# Processing: Body Composition Analyzers Market.docx
# Processing: Body Contouring Devices Market.docx
# Processing: Bone Conduction Devices Market.docx
# Processing: Bone Grafts and Substitutes Market.docx
# Processing: Bone Spur Market.docx
# Processing: Brain Imaging Devices Market.docx
# Processing: Brain Ischemia Market.docx
# Processing: Brain PET MRI System Market.docx
# Processing: Breast Biopsy Devices Market.docx
# Processing: Bronchoscopes Market.docx
# Processing: Buccal Cavity Devices Market.docx
# Processing: Bunion Correction System Market.docx
# Processing: Capillary Blood Collection Devices Market.docx
# Processing: Carbon Dioxide (CO2) Monitor Market Report.docx
# Processing: Cardiac AI Monitoring And Diagnostics Market.docx
# Processing: Cardiology Information System Market.docx
# Processing: Cardiopulmonary Stress Testing Market.docx
# Processing: Cardiovascular Needle Market.docx
# Processing: Carpal Tunnel Release System Market.docx
# Processing: Catheter Introducer Sheaths Market.docx
# Processing: Cell Culture Sampling Device Market.docx
# Processing: Cell-Based Assay Market.docx
# Processing: Cementless Total Knee Arthroplasty (TKA) Market.docx
# Processing: Ceramic Armor Market.docx
# Processing: Cerebrospinal Fluid Management Market.docx
# Processing: Cervical Dysplasia Market.docx
# Processing: Cervical Fusion Market.docx
# Processing: CGRP Inhibitors Market.docx
# Processing: Chemical Peel Market.docx
# Processing: Chemiluminescence Immunoassay Market.docx
# Processing: chemotherapy infusion pumps market.docx
# Processing: chiral chromatography columns market.docx
# Processing: Chlamydia Diagnostics Market.docx
# Processing: Cholesterol Management Devices Market.docx
# Processing: Cholesterol Testing Market.docx
# Processing: Chronic Heart Failure Market.docx
# Processing: Cleaning Robot Market.docx
# Processing: Clear Aligners Market.docx
# Processing: coagulation analyzer market.docx
# Processing: Cochlear Implants Market.docx
# Processing: Cockpit Lighting Market.docx
# Processing: Collagen Dressing Market.docx
# Processing: Colorectal Cancer Screening Market.docx
# Processing: Colorectal Surgery Market.docx
# Processing: Colposcopy Market.docx
# Processing: Commercial Aircraft Cabin Interior Market.docx
# Processing: Commercial Aircraft Cabin Seating Market.docx
# Processing: Commercial Aircraft FADEC Market.docx
# Processing: Commercial Aircraft In-Seat Power System Market.docx
# Processing: Commercial Aircraft Video Surveillance System Market.docx
# Processing: Commercial Hovercraft Market.docx
# Processing: Companion Diagnostics Market.docx
# Processing: Cone Beam Computed Tomography Market.docx
# Processing: Confocal Microscope Market.docx
# Processing: Contraceptive Devices Market.docx
# Processing: COPD And Asthma Devices Market.docx
# Processing: Corneal Surgery Devices Market.docx
# Processing: Creatinine Test Market.docx
# Processing: Cryotherapy Market.docx
# Processing: CyberKnife Market.docx
# Processing: Cytoscope Market.docx
# Processing: Decoy Flares Market.docx
# Processing: Defense Integrated Antenna Market.docx
# Processing: Defense Tactical Radio Market.docx
# Processing: Dental 3D Scanners Market.docx
# Processing: Dental Articulators Market.docx
# Processing: Dental Bone Void Filler Market.docx
# Processing: Dental Burs Market.docx
# Processing: Dental Filling Market.docx
# Processing: Dental Imaging Market.docx
# Processing: Dental Implants Market.docx
# Processing: Dental Intraoral Sensors Market.docx
# Processing: Dental Microscope Market.docx
# Processing: Dental Microsurgery Market.docx
# Processing: Dental Milling Machine Market.docx
# Processing: Dental Sterilization Market.docx
# Processing: Dental Syringes Market.docx
# Processing: Dental Trauma Market.docx
# Processing: Dermal Fillers Market.docx
# Processing: Dermatology Devices Market.docx
# Processing: Dermatology Excimer Laser Market.docx
# Processing: Diabetic Foot Ulcer Treatment Market.docx
# Processing: Diagnostic Catheter Market.docx
# Processing: Diagnostic Specialty Antibodies Market.docx
# Processing: Diathermy Equipment Market.docx
# Processing: Digital Dose Inhaler Market.docx
# Processing: Digital Immune System Market.docx
# Processing: Digital Neurotherapeutics Market.docx
# Processing: Digital Surgical Microscopes Market.docx
# Processing: Digital Wound Measurement Devices Market.docx
# Processing: Disposable Blood Bags Market.docx
# Processing: Disposable Negative Pressure Wound Therapy (NPWT) Devices market.docx
# Processing: Disposable Surgical Devices Market.docx
# Processing: Distraction Osteogenesis Devices Market.docx
# Processing: Dried Blood Spot Collection Cards Market.docx
# Processing: Driver Monitoring System Market.docx
# Processing: Drug Abuse Testing Market.docx
# Processing: Drug Screening Market.docx
# Processing: Dual Chamber Prefilled Syringes Market.docx
# Processing: Dysphagia Management Market.docx
# Processing: E Beam Wafer Inspection System market.docx
# Processing: E-Bomb Market.docx
# Processing: E.Coli Testing Market.docx
# Processing: ECG Electrodes Market.docx
# Processing: Efficacy Testing Market.docx
# Processing: Electric Boat Market.docx
# Processing: Electro Medical and Electrotherapeutic Apparatus Market.docx
# Processing: Electromyography (EMG) Devices Market.docx
# Processing: Electron Microscopy Market.docx
# Processing: Electronic Skin Patch Market.docx
# Processing: Electrotherapy Market.docx
# Processing: ELISA Analyzers Market.docx
# Processing: Elispot and Fluorospot Assay Market.docx
# Processing: Endodontics Market.docx
# Processing: Endoscope Drying Cabinets Market.docx
# Processing: Endoscopy Visualization Systems Market.docx
# Processing: ENT Devices Market.docx
# Processing: Enzyme-Linked Immunosorbent Assay (ELISA) Market.docx
# Processing: EO-IR Gimbal Market.docx
# Processing: Epilepsy Drugs Market.docx
# Processing: Erectile Dysfunction (ED) Devices Market.docx
# Processing: Erectile Dysfunction Drugs Market.docx
# Processing: ESG Reporting Software Market.docx
# Processing: eVTOL Aircraft Market.docx
# Processing: Exoskeleton Market.docx
# Processing: Explosive Ordnance Disposal (EOD) Equipment Market.docx
# Processing: Exposure Management Market.docx
# Processing: External Pacemaker Market.docx
# Processing: External Ventricular Drain (EVD) Market.docx
# Processing: Extracorporeal CO2 Removal Devices Market.docx
# Processing: Facial Injectable Market.docx
# Processing: Facial Palsy Market.docx
# Processing: Feminine Hygiene Products Market.docx
# Processing: Feno Measuring Devices Market.docx
# Processing: Fetal And Neonatal Care Equipment Market.docx
# Processing: Fetal And Neonatal Heart Monitor Market.docx
# Processing: Fetal Monitoring Market.docx
# Processing: Flexible Endoscopes Market.docx
# Processing: Fluorescence Guided Surgery System Market.docx
# Processing: Fluoroscopy Equipment Market.docx
# Processing: Foregut Surgery Devices Market.docx
# Processing: Fractional Flow Reserve (FFR) Market.docx
# Processing: Fracture Fixation Products Market.docx
# Processing: Fundus Cameras Market.docx
# Processing: Gamma Probe Devices Market.docx
# Processing: Gas Chromatography Market.docx
# Processing: Gastroretentive Drug Delivery Systems Outsourcing Market.docx
# Processing: Glaucoma Surgery Devices Market.docx
# Processing: Global Butterfly Needle Set Market.docx
# Processing: Global Ground Fault Relays Market.docx
# Processing: Global Skin Grafting Devices Market.docx
# Processing: Global Small Animal Imaging Market.docx
# Processing: Global Suture Needles Market.docx
# Processing: Glucagon Delivery Devices Market.docx
# Processing: gynecological examination chairs market.docx
# Processing: Head and Neck Cancer Therapeutics Market.docx
# Processing: Hearing Screening Diagnostic Devices Market.docx
# Processing: Heart Attack Diagnostics Market.docx
# Processing: Heart Transplantation Therapeutics Market.docx
# Processing: Helicopter Seats Market.docx
# Processing: Hemato Oncology Testing Market.docx
# Processing: Hemodialysis Vascular Grafts Market.docx
# Processing: Hemorrhoid Treatment Devices Market.docx
# Processing: Hepatitis Testing Market.docx
# Processing: Hernia Repair Devices Market.docx
# Processing: Hi-Tech Medical Devices Market.docx
# Processing: High Altitude Platform Market.docx
# Processing: High Flow Nasal Cannula (HFNC) Market.docx
# Processing: High Tibial Osteotomy Plates Market.docx
# Processing: High Voltage Switchboard Market.docx
# Processing: Holter ECG Monitoring Market.docx
# Processing: home infusion therapy market.docx
# Processing: Home Sleep Apnea Testing Market.docx
# Processing: Home Sleep Screening Devices Market.docx
# Processing: Hosted PBX Market.docx
# Processing: Human Metapneumovirus Diagnostics Market.docx
# Processing: HVAC Software Market.docx
# Processing: Hyaluronic Acid Market.docx
# Processing: Hybrid Boats Market.docx
# Processing: Hydrocephalus Shunts Market.docx
# Processing: Hydrogen Hubs Market.docx
# Processing: Immunohistochemistry Market.docx
# Processing: Implantable Cardiac Rhythm Management (CRM) Devices Market.docx
# Processing: In Silico Clinical Trials Market.docx
# Processing: In-Dash Navigation System Market.docx
# Processing: In-Space Manufacturing Market .docx
# Processing: incontinence care products market.docx
# Processing: Infant Radiant Warmer Market.docx
# Processing: Infusion Pumps Market.docx
# Processing: Ingestible Sensors Market.docx
# Processing: Inhaled Corticosteroid Device Market.docx
# Processing: Injection Pen Market.docx
# Processing: Insulin Pump Market.docx
# Processing: Insulin Syringes Market.docx
# Processing: Intra-cardiac electrophysiology mapping catheters market.docx
# Processing: Intraoperative Imaging Market.docx
# Processing: IV Pole Market.docx
# Processing: IV Tubing Sets And Accessories Market.docx
# Processing: Kidney Stone Retrieval Devices Market.docx
# Processing: Kidney Transplant Medicine Market.docx
# Processing: Kyphosis Treatment Market.docx
# Processing: Lab Consumables Market.docx
# Processing: Lacrimal Devices Market.docx
# Processing: Laparoscopic Retrieval Bags Market.docx
# Processing: LASIK Eye Surgery Devices Market.docx
# Processing: Legal AI Software Market.docx
# Processing: Leo Terminal Market.docx
# Processing: Liver Biopsy Market.docx
# Processing: Liver Cancer Diagnostics Market.docx
# Processing: Livestock Identification Market.docx
# Processing: Lyme Disease Testing Market.docx
# Processing: Magnetoencephalography Market.docx
# Processing: Malaria Diagnostics Market.docx
# Processing: Manual Resuscitators Market.docx
# Processing: Marine Onboard Communication Control System Market.docx
# Processing: Marine Pump Market.docx
# Processing: Marine Turbocharger Market.docx
# Processing: Mechanical Ventilator Market.docx
# Processing: Medical Device Cuffs Market.docx
# Processing: Medical Foam Market.docx
# Processing: Medical Imaging Phantoms Market.docx
# Processing: Medical Swab Market.docx
# Processing: Menopause Market.docx
# Processing: Menstrual Cup Market.docx
# Processing: Mesotherapy Market.docx
# Processing: Microbiology Testing Market.docx
# Processing: Microcatheter Market.docx
# Processing: Microfluidics Market.docx
# Processing: Microplate Reader Market.docx
# Processing: Midline Catheter Market.docx
# Processing: Military Fitness Training Equipment Market.docx
# Processing: Military GPS Receiver Market.docx
# Processing: Military Transmit And Receive Module Market.docx
# Processing: Military Vehicle Electrification Market.docx
# Processing: Military wearables market.docx
# Processing: miRNA Sequencing and Assay Market.docx
# Processing: Missile Guidance System Market.docx
# Processing: Molecular Imaging Market.docx
# Processing: Mononucleosis Diagnostics Market.docx
# Processing: Mortar Fire Control Computer Market.docx
# Processing: Mortar System Market.docx
# Processing: MRI Compatible IV Infusion Pumps Market.docx
# Processing: Multi-Omics Market.docx
# Processing: Multiparameter Patient Monitoring System Market.docx
# Processing: Multispectral Camera Market.docx
# Processing: Myocardial Infarction Market.docx
# Processing: Myocardial Ischemia Market.docx
# Processing: Nanomedicine market.docx
# Processing: Nanorobotics Market.docx
# Processing: Nasal Cannula Market.docx
# Processing: Near Infrared Imaging Market.docx
# Processing: Nebulizer Market.docx
# Processing: Neonatal Ventilator Market.docx
# Processing: Nephrology and Urology Devices Market.docx
# Processing: Neurophotonics Market.docx
# Processing: Newborn Screening Market.docx
# Processing: Non-Invasive Blood Glucose Monitoring Market.docx
# Processing: non-invasive brain trauma monitoring devices market.docx
# Processing: Non-Invasive Fat Reduction Market.docx
# Processing: Non-PVC IV Bags Market.docx
# Processing: Obstetrics & Gynecology Ultrasound Devices Market.docx
# Processing: Oncology Based Molecular Diagnostics Market.docx
# Processing: Open MRI Systems Market.docx
# Processing: ophthalmic drug delivery systems market.docx
# Processing: Ophthalmic Eye Dropper Market.docx
# Processing: Ophthalmic Handheld Surgical Instruments Market.docx
# Processing: Ophthalmic Loupes Market.docx
# Processing: Ophthalmic Suspension Market.docx
# Processing: ophthalmic viscoelastic devices market.docx
# Processing: Ophthalmology Diagnostics Market.docx
# Processing: Optical Imaging Market.docx
# Processing: Optical Satellite Communication Market.docx
# Processing: Oral Solid Dosage CDMO Market.docx
# Processing: Oral Solid Dosage Contract Manufacturing Market.docx
# Processing: Organ Transplant Immunosuppressant Drugs Market.docx
# Processing: Orthodontic Headgear Market.docx
# Processing: Orthokeratology Lens Market.docx
# Processing: Orthopedic Braces and Supports Market.docx
# Processing: Orthopedic Implants Market.docx
# Processing: Osteosarcoma Market.docx
# Processing: Ostomy Care and Accessories Market.docx
# Processing: Ostomy Drainage Bags Market.docx
# Processing: OTC Glucose Monitors Market.docx
# Processing: Otoplasty Market.docx
# Processing: over the counter (OTC) test market.docx
# Processing: Oxygen Concentrators Market.docx
# Processing: Oxygen Conservation Devices Market.docx
# Processing: Oxygen Therapy Equipment Market.docx
# Processing: Paper Diagnostics Market.docx
# Processing: Paraneoplastic Syndrome Market.docx
# Processing: Patient Handling Equipment Market.docx
# Processing: Patient Lateral Transfer Market.docx
# Processing: Patient Positioning Systems.docx
# Processing: Patient Temperature Monitoring Market.docx
# Processing: patient-derived xenograft model market.docx
# Processing: Pediatric Neurology Devices Market.docx
# Processing: Pediatric Orthopedic Devices Market.docx
# Processing: Pediatric Palliative Care Market.docx
# Processing: Pedicle Screw System Market.docx
# Processing: PEEK Surgical Screws Market.docx
# Processing: Penile Implants Market.docx
# Processing: Perfusion Radiology Market.docx
# Processing: perfusion system market.docx
# Processing: Photoacoustic Imaging Market.docx
# Processing: Physiotherapy Equipment Market.docx
# Processing: Phytopathological Disease Diagnostics Market.docx
# Processing: Pipette Controller Market.docx
# Processing: Pneumatic Nebulizer Market.docx
# Processing: Point Of Care Coagulation Testing Devices Market.docx
# Processing: Point Of Care Glucose Testing Market.docx
# Processing: Polyp Biopsy Market.docx
# Processing: Portable Gas Chromatograph Market.docx
# Processing: Portable Ventilator Market.docx
# Processing: Precision Oncology Market.docx
# Processing: Preclinical Imaging Market.docx
# Processing: Predictive Presymptomatic Testing Market.docx
# Processing: Prefilled Syringes Market.docx
# Processing: Preterm Birth Prevention And Management Market.docx
# Processing: Procurement Software Market.docx
# Processing: Product Configurator Market.docx
# Processing: Programmable Ammunition Market.docx
# Processing: Prostate Specific Antigen Testing Market.docx
# Processing: Prostatic Hyperplasia (BPH) Devices Market.docx
# Processing: Protein Assays Market.docx
# Processing: Protein Stability Analysis Market.docx
# Processing: Proton Pump Inhibitors (PPI) Market.docx
# Processing: PTA Balloon Catheter Market.docx
# Processing: Pulse Lavage Market.docx
# Processing: Radial Artery Compression Devices Market.docx
# Processing: Radioimmunoassay Market.docx
# Processing: Rail Gearbox Market.docx
# Processing: Recreational Oxygen Equipment Market.docx
# Processing: Reflux Testing Products Market.docx
# Processing: Regenerative Medicine Market.docx
# Processing: Rehabilitation Equipment Market.docx
# Processing: Remote Weapon Station Market.docx
# Processing: Renal Biomarkers Market .docx
# Processing: Reprocessed Medical Devices Market.docx
# Processing: Respiratory and Anesthesia Disposables Market.docx
# Processing: Respiratory Care Devices Market.docx
# Processing: Resuscitation Devices Market.docx
# Processing: Retinal Implants Market.docx
# Processing: Reusable Blood Hemodialyzer Market.docx
# Processing: Rheometer And Viscometer Market.docx
# Processing: Robotic Nurse Assistant Market.docx
# Processing: Robotic Vacuum Cleaner Market.docx
# Processing: Rotator Cuff Injury Treatment Market.docx
# Processing: Safety Lancets Market.docx
# Processing: Satellite Attitude and Orbit Control System (AOCS) Market.docx
# Processing: Sclerotherapy Market.docx
# Processing: Self-Injection Devices Market.docx
# Processing: Self-Monitoring Blood Glucose (SMBG) Devices Market.docx
# Processing: Sentinel Node Biopsy Market.docx
# Processing: Sex Reassignment Surgery Market.docx
# Processing: Shotgun And Rifles Market.docx
# Processing: Silver Wound Dressing Market.docx
# Processing: Sinus Dilation Devices Market.docx
# Processing: Skin Boosters Market.docx
# Processing: Skin Resurfacing Market.docx
# Processing: Sleep Apnea Implants Market.docx
# Processing: Smart Inhalers Market.docx
# Processing: Smart Orthopedic Implants Market.docx
# Processing: Smart Pills Market.docx
# Processing: Smart Stethoscope Market.docx
# Processing: Smart Textiles Market.docx
# Processing: Space Based Solar Power Market.docx
# Processing: Space In-Orbit Refueling Market.docx
# Processing: Space Militarization Market.docx
# Processing: Space Power Electronics Market.docx
# Processing: Space Traffic Management Market.docx
# Processing: Specimen Retrieval Market.docx
# Processing: Spinal Needles Market.docx
# Processing: Spine Surgery Robots Market.docx
# Processing: Spirometer Market.docx
# Processing: Stable Isotope Labeled Compounds Market.docx
# Processing: STD Diagnostics Market.docx
# Processing: Stereotactic Surgery Devices Market.docx
# Processing: Sterility Indicators Market.docx
# Processing: Sternal Closure Systems Market.docx
# Processing: Stress Tracking Devices Market.docx
# Processing: Supercritical Fluid Chromatography Market.docx
# Processing: Supraglottic Airway Devices Market.docx
# Processing: Surgical Chips Market.docx
# Processing: Surgical Clips Market.docx
# Processing: Surgical Display Market.docx
# Processing: Surgical Dressings Market.docx
# Processing: Surgical Gowns Market.docx
# Processing: Surgical Polypropylene Mesh Market.docx
# Processing: Surgical Snare Market.docx
# Processing: Surgical Sphincteroplasty Market.docx
# Processing: Surgical Stents Market.docx
# Processing: Syndromic Multiplex Diagnostics Market.docx
# Processing: Tachycardia Market.docx
# Processing: Teleradiology Market.docx
# Processing: Telescopic Mast Market.docx
# Processing: Teleultrasound System Market.docx
# Processing: Therapeutic Respiratory Devices Market.docx
# Processing: Thermal Management Market.docx
# Processing: Thoracic Drainage Devices Market.docx
# Processing: Thyroid Function Test Market.docx
# Processing: Tinnitus Management Market.docx
# Processing: Tip Location Devices Market.docx
# Processing: Tissue Diagnostics Market.docx
# Processing: Tonometer Market.docx
# Processing: Topical Drug Delivery Market.docx
# Processing: Topical Drugs Contract Manufacturing Market.docx
# Processing: Topical Scar Treatment Market.docx
# Processing: Total Reflection X-Ray Fluorescence (TXRF) Spectrometer Market.docx
# Processing: Toxicology Drug Screening Market.docx
# Processing: tracheostomy products market.docx
# Processing: Transcranial Magnetic Stimulator Market.docx
# Processing: Transcutaneous Bilirubinometer Market.docx
# Processing: Transcutaneous Oximetry System Market.docx
# Processing: Transdermal Patches Market.docx
# Processing: Transfection Reagents And Equipment Market.docx
# Processing: Transplant Diagnostics Market.docx
# Processing: Traveling Wave Tubes (TWT) Market.docx
# Processing: Trichoscope Devices Market.docx
# Processing: Trocars Market.docx
# Processing: Truck Rental Market.docx
# Processing: Tuberculosis (TB) Testing Market.docx
# Processing: Tympanostomy Products Market.docx
# Processing: Tympanostomy Tubes Market.docx
# Processing: Ultrasonic Scalpel Market.docx
# Processing: Ultrasound Needle Guides Market.docx
# Processing: Ultrasound Probe Disinfection Market.docx
# Processing: Ultrasound Transducer Market.docx
# Processing: Unit Dose Packaging Market.docx
# Processing: Urinalysis Market.docx
# Processing: Urinary Incontinence Devices Market.docx
# Processing: Urodynamic Equipment And Consumables Market.docx
# Processing: UV Disinfection Equipment Market.docx
# Processing: Uveal Melanoma Market.docx
# Processing: Vaginitis Therapeutics Market.docx
# Processing: Varicose Vein Treatment Market.docx
# Processing: vascular patches market.docx
# Processing: Vascular Stents Market.docx
# Processing: Venipuncture Needle And Syringes Market.docx
# Processing: Vertebroplasty and Kyphoplasty Market.docx
# Processing: Vessel Sealing Devices Market.docx
# Processing: vibrating mesh nebulizer market.docx
# Processing: Virology Specimen Collection Market.docx
# Processing: Virus Filtration Market.docx
# Processing: Vital Signs Monitoring Devices Market.docx
# Processing: Vitreoretinal Surgery Devices Market.docx
# Processing: Wearable Breast Pumps Market..docx
# Processing: Weight Management Devices Market.docx
# Processing: Wireless Brain Sensors Market.docx
# Processing: Wireless Gigabit Market.docx
# Processing: Zero Emission Aircraft Market.docx
# ✅ Done! Extracted data saved in C:\Users\Vishnu\Documents\extracted_docs\Extraction.xlsx
